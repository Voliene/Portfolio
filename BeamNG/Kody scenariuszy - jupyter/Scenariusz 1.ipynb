# %%
from beamngpy import BeamNGpy, Scenario, Vehicle   
import time  
import numpy as np
import matplotlib.pyplot as plt
import sounddevice as sd
import soundfile as sf
# Instantiate BeamNGpy instance running the simulator from the given path,
# communicating over localhost:64256
bng = BeamNGpy(
    "localhost",
    64256,
    home=r"C:\\Users\bp50929\Desktop\BeamNG.tech.v0.31.3.0\BeamNG.tech.v0.31.3.0",
    user=r"C:\\Users\bp50929\AppData\\Local\BeamNG.drive",
)
# Launch BeamNG.tech
bng.open()

# %%
vehicle1 = Vehicle("Traffic1", model="etk800", license="Traffic1", color='blue')
vehicle2 = Vehicle("Traffic2", model="pickup", license="Traffic2", color='purple')
vehicle3 = Vehicle("Traffic3", model="pessima", license="Traffic3", color='yellow')
vehicle4 = Vehicle("Traffic4", model="van", license="Traffic4", color='red', color2='black')
vehicle = Vehicle("ego_vehicle", model="burnside", license="ZUT")
vehicle5 = Vehicle("Traffic5", model="bluebuck", license="Traffic5", color='green')
vehicle6 = Vehicle("TESTER", model="bastion", license="TESTER", color='blue')
#print(bng.vehicles.get_available())
# Out:
# data: {'type': 'GetAvailableVehicles'}
# {'type': 'AvailableVehicles', 'vehicles': {'shipping_container': {'name': 'Shipping Container', 'type': 'Prop', 'configurations': {'container_40ft_empty': {'model_key': 'shipping_container', 'name': 'Shipping Container 40ft - Empty', 'key': 'container_40ft_empty'}, 'container_tank_milk': {'model_key': 'shipping_container', 'name': 'Shipping Container 20ft Tank - 18000L Milk', 'key': 'container_tank_milk'}, 'container_tank_empty': {'model_key': 'shipping_container', 'name': 'Shipping Container 20ft Tank - Empty', 'key': 'container_tank_empty'}, 'container_20ft_12t': {'model_key': 'shipping_container', 'name': 'Shipping Container 20ft - 12000kg Load', 'key': 'container_20ft_12t'}, 'container_tank_water': {'model_key': 'shipping_container', 'name': 'Shipping Container 20ft Tank - 18000L Water', 'key': 'container_tank_water'}, 'container_40ft_12t': {'model_key': 'shipping_container', 'name': 'Shipping Container 40ft - 12000kg Load', 'key': 'container_40ft_12t'}, 'container_40ft_7t': {'model_key': 'shipping_container', 'name': 'Shipping Container 40ft - 7000kg Load', 'key': 'container_40ft_7t'}, 'container_20ft_empty': {'model_key': 'shipping_container', 'name': 'Shipping Container 20ft - Empty', 'key': 'container_20ft_empty'}, 'container_40ft_24t': {'model_key': 'shipping_container', 'name': 'Shipping Container 40ft - 24000kg Load', 'key': 'container_40ft_24t'}, 'container_20ft_6t': {'model_key': 'shipping_container', 'name': 'Shipping Container 20ft - 6000kg Load', 'key': 'container_20ft_6t'}}, 'key': 'shipping_container', 'author': 'BeamNG'}, 'frameless_dump': {'name': 'Frameless Dump Trailer', 'type': 'Trailer', 'configurations': {'wide_double': {'model_key': 'frameless_dump', 'name': 'Frameless Dump Trailer Wide Spread Double Axle', 'key': 'wide_double'}, 'double': {'model_key': 'frameless_dump', 'name': 'Frameless Dump Trailer Double Axle', 'key': 'double'}, 'triple': {'model_key': 'frameless_dump', 'name': 'Frameless Dump Trailer Triple Axle', 'key': 'triple'}}, 'key': 'frameless_dump', 'author': 'BeamNG'}, 'cargotrailer': {'name': 'Enclosed Cargo Trailer', 'type': 'Trailer', 'configurations': {'loaded_armchairs': {'model_key': 'cargotrailer', 'name': 'Enclosed Cargo Trailer Armchairs', 'key': 'loaded_armchairs'}, 'loaded_planks_long': {'model_key': 'cargotrailer', 'name': 'Enclosed Cargo Trailer 2100kg Planks', 'key': 'loaded_planks_long'}, 'loaded_planks': {'model_key': 'cargotrailer', 'name': 'Enclosed Cargo Trailer 1400kg Planks', 'key': 'loaded_planks'}, 'loaded_800': {'model_key': 'cargotrailer', 'name': 'Enclosed Cargo Trailer 800kg Crate', 'key': 'loaded_800'}, 'loaded_400': {'model_key': 'cargotrailer', 'name': 'Enclosed Cargo Trailer 400kg Crate', 'key': 'loaded_400'}, 'default': {'model_key': 'cargotrailer', 'name': 'Enclosed Cargo Trailer Unloaded', 'key': 'default'}, 'loaded_couch': {'model_key': 'cargotrailer', 'name': 'Enclosed Cargo Trailer Couch', 'key': 'loaded_couch'}}, 'key': 'cargotrailer', 'author': 'BeamNG'}, 'large_hamster_wheel': {'name': 'Large Hamster Wheel', 'type': 'Prop', 'configurations': {'large_hamster_wheel': {'model_key': 'large_hamster_wheel', 'name': 'Large Hamster Wheel', 'type': 'Prop', 'key': 'large_hamster_wheel', 'author': 'BeamNG'}}, 'key': 'large_hamster_wheel', 'author': 'BeamNG'}, 'roadsigns': {'name': 'Road Sign', 'type': 'Prop', 'configurations': {'squiggle': {'model_key': 'roadsigns', 'name': 'Road Sign Winding Road Sign', 'key': 'squiggle'}, 'stop': {'model_key': 'roadsigns', 'name': 'Road Sign Stop Sign', 'key': 'stop'}, 'turn_L': {'model_key': 'roadsigns', 'name': 'Road Sign Left Turn Sign', 'key': 'turn_L'}, 'slow': {'model_key': 'roadsigns', 'name': 'Road Sign Slow Sign', 'key': 'slow'}, '55mph': {'model_key': 'roadsigns', 'name': 'Road Sign 55 MPH Speed Limit Sign', 'key': '55mph'}, '65mph': {'model_key': 'roadsigns', 'name': 'Road Sign 65 MPH Speed Limit Sign', 'key': '65mph'}, 'uturn_R': {'model_key': 'roadsigns', 'name': 'Road Sign Right U-Turn Sign', 'key': 'uturn_R' ...

# %%
scenario2 = Scenario("polish_roads_v2", "Mission 1",)

scenario2.add_vehicle(
vehicle, pos=(440.91, 754.78, -18.5), rot_quat=(0, 0, 1, 0)
)
scenario2.add_vehicle(
vehicle3, pos=(430, 754.78, -18.5), rot_quat=(0, 0, 1, 0)
)
scenario2.add_vehicle(
vehicle4, pos=(420, 754.78, -18.5), rot_quat=(0, 0, 1, 0)
)
scenario2.add_vehicle(
vehicle5, pos=(410, 754.78, -18.5), rot_quat=(0, 0, 1, 0)
)
scenario2.add_vehicle(
vehicle6, pos=(400, 754.78, -18.5), rot_quat=(0, 0, 1, 0)
)
scenario2.add_vehicle(
vehicle1, pos=(462.9, 627.44, -18.6), rot_quat=(0, 0, 1, 0)
)
scenario2.add_vehicle(
vehicle2, pos=(470, 754.78, -18.5), rot_quat=(0, 0, 1, 0)
)

scenario2.make(bng)

# %%
bng.scenario.load(scenario2)
vehicle.switch()
bng.scenario.start()

# %%
skrypt = [{
        "t":2.18150012,
        "x":461.8789999,
        "y":629.2753332,
        "z":-17.83815008
      },
      {
        "t":2.684000155,
        "x":461.6548465,
        "y":629.8794334,
        "z":-17.75922883
      },
      {
        "t":3.738500213,
        "x":459.9725994,
        "y":634.4698079,
        "z":-17.34934193
      },
      {
        "t":4.37350023,
        "x":458.2870933,
        "y":638.8417367,
        "z":-17.04040784
      },
      {
        "t":4.920000253,
        "x":456.0822548,
        "y":643.163537,
        "z":-16.8616339
      },
      {
        "t":5.792000288,
        "x":452.2270603,
        "y":651.3754852,
        "z":-16.79522932
      },
      {
        "z":-16.86919963
      },
      {
        "t":22.93400106,
        "x":317.4511514,
        "y":717.1333721,
        "z":-16.86544693
      },
      {
        "t":23.24950108,
        "x":317.327121,
        "y":717.1370217,
        "z":-16.84507871
      },
      {
        "t":23.51400109,
        "x":317.3289587,
        "y":717.1355383,
        "z":-16.82993346
      },
      {
        "t":23.77450111,
        "x":317.3255813,
        "y":717.1362391,
        "z":-16.83059239
      },
      {
        "t":24.09550112,
        "x":317.3200803,
        "y":717.1366459,
        "z":-16.8272025
      },
      {
        "t":24.52300114,
        "x":317.3221591,
        "y":717.1365966,
        "z":-16.82879227
      },
      {
        "t":24.90950116,
        "x":317.3193698,
        "y":717.1367999,
        "z":-16.82739085
      }]

vehicle6.ai.set_target("ego_vehicle","follow")
vehicle6.ai.set_mode('follow')
# data, fs = sf.read('C:\\Users\\bp50929\AppData\Local\BeamNG.drive\\0.31\sounds\car-horn-3-191449.mp3', dtype='float32')
# sd.play(data, fs)

for i in range (1000):
  time.sleep(5)
  vehicle1.ai.execute_script(skrypt)
  time.sleep(5)
  vehicle2.ai.execute_script(skrypt)
  time.sleep(5)
  vehicle3.ai.execute_script(skrypt)
  time.sleep(5)
  vehicle4.ai.execute_script(skrypt)
  time.sleep(5)
  vehicle5.ai.execute_script(skrypt)
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\beamngpy\connection\prefixed_length_socket.py:35, in PrefixedLengthSocket._recv_exactly(self, length)
#      34 try:
# ---> 35     received = self.skt.recv(min(BUF_SIZE, length))
#      36 except socket.error:
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[59], line 305
#     303 vehicle4.ai.execute_script(skrypt)
#     304 time.sleep(5)
# --> 305 vehicle5.ai.execute_script(skrypt)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\beamngpy\api\vehicle\ai.py:178, in AIApi.execute_script(self, script, cling, start_delay, no_reset)
#     176 data['startDelay'] = start_delay
#     177 data['noReset'] = no_reset
# --> 178 self._send(data).ack('CompletedExecuteScript')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\beamngpy\connection\connection.py:275, in Response.ack(self, ack_type)
#     274 def ack(self, ack_type: str) -> None:
# --> 275     message = self.recv()
#     276     if message['type'] != ack_type:
#     277         raise BNGError(f'Wrong ACK: {ack_type} != {message["type"]}')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\beamngpy\connection\connection.py:267, in Response.recv(self, type)
#     266 def recv(self, type: str | None = None) -> StrDict:
# --> 267     message = self.connection.recv(self.req_id)
#     268     if isinstance(message, Exception):
#     269         raise message
#
# File ~\AppData\Roaming\Python\Python311\site-packages\beamngpy\connection\connection.py:209, in Connection.recv(self, req_id)
#     207     raise BNGError('Cannot receive, not connected to the simulator.')
#     208 while True:
# --> 209     message = self.skt.recv()
#     210     message = self._unpack_data(message)
#     211     if not '_id' in message:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\beamngpy\connection\prefixed_length_socket.py:63, in PrefixedLengthSocket.recv(self)
#      62 def recv(self) -> bytes:
# ---> 63     packed_length = self._recv_exactly(self.HEADER_BYTES)
#      64     length = unpack('!I', packed_length)[0]
#      66     message = self._recv_exactly(length)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\beamngpy\connection\prefixed_length_socket.py:37, in PrefixedLengthSocket._recv_exactly(self, length)
#      35     received = self.skt.recv(min(BUF_SIZE, length))
#      36 except socket.error:
# ---> 37     self.reconnect()
#      38     received = self.skt.recv(min(BUF_SIZE, length))
#      39 if not received:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\beamngpy\connection\prefixed_length_socket.py:82, in PrefixedLengthSocket.reconnect(self)
#      80 while tries > 0:
#      81     try:
# ---> 82         self.skt.connect((self.host, self.port))
#      83         break
#      84     except (ConnectionRefusedError, ConnectionAbortedError):
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
bng.traffic.spawn(2)
